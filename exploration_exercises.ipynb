# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr, spearmanr
from sklearn.model_selection import train_test_split
from acquire import get_zillow_data
from wrangle import wrangle_zillow

# %%
df = get_zillow_data()

# %%
df.head()
# Out:
#    bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  taxvaluedollarcnt  \
# 0         0.0          0.0                           NaN            27516.0
# 1         0.0          0.0                           NaN               10.0
# 2         0.0          0.0                           NaN               10.0
# 3         0.0          0.0                           NaN             2108.0
# 4         4.0          2.0                        3633.0           296425.0
#
#    yearbuilt  taxamount    fips
# 0        NaN        NaN  6037.0
# 1        NaN        NaN  6037.0
# 2        NaN        NaN  6037.0
# 3        NaN     174.21  6037.0
# 4     2005.0    6941.39  6037.0

# %%
train, validate, test = wrangle_zillow()

# %%
train.shape, validate.shape, test.shape
# Out:
# ((1192919, 7), (511252, 7), (426043, 7))

# %%
train.head()
# Out:
#          bedrooms  bathrooms  square_feet  tax_value  year_built  tax_amount  \
# 553191          4        2.0         1556     373090        1923     4579.25
# 1209132         3        2.0         1513      74070        1937      986.55
# 174634          4        2.0         2040     138000        1954     2553.05
# 170584          3        2.0         1834     263870        1959     3139.76
# 2001226         2        2.0         1225     335603        1975     3461.38
#
#          fips
# 553191   6037
# 1209132  6037
# 174634   6037
# 170584   6059
# 2001226  6059

# %%
train.year_built.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 553191     1923
# 1209132    1937
# 174634     1954
# 170584     1959
# 2001226    1975
#            ...
# 562147     1956
# 1530656    1950
# 745152     1957
# 249374     1920
# 1333156    1969
# Name: year_built, Length: 1192919, dtype: int64>

# %%
cont_var = ['square_feet', 'tax_amount', 'tax_value', 'year_built']

# %%
for col in cont_var:
    
    plt.hist(train[col], bins=35)
    plt.title(f'{col} distribution')
    plt.show()

# %%
cat_var = ['bedrooms', 'bathrooms', 'fips']
    
for col in cat_var:

    
    plt.hist(train[col], bins=25)
    plt.title(f'{col} distribution')
    plt.show()

# %%
train_corr = train[cont_var].corr(method='spearman')
train_corr
# Out:
#              square_feet  tax_amount  tax_value  year_built
# square_feet     1.000000    0.521105   0.523403    0.512313
# tax_amount      0.521105    1.000000   0.978623    0.289341
# tax_value       0.523403    0.978623   1.000000    0.290691
# year_built      0.512313    0.289341   0.290691    1.000000

# %%
sns.heatmap(train_corr, cmap='Purples', annot=True, linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
train_corr2 = train[cat_var].corr(method='spearman')
train_corr2
# Out:
#            bedrooms  bathrooms      fips
# bedrooms   1.000000   0.634164  0.177891
# bathrooms  0.634164   1.000000  0.184929
# fips       0.177891   0.184929  1.000000

# %%
sns.heatmap(train_corr2, cmap='Purples', annot=True, linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x='tax_value', y='square_feet', data=train.sample(1000), scatter=True)
sns.lmplot(x='tax_value', y='year_built', data=train.sample(1000), scatter=True)
sns.lmplot(x='tax_value', y='tax_amount', data=train.sample(1000), scatter=True)

# %%
cont_var
# Out:
# ['square_feet', 'tax_amount', 'tax_value', 'year_built']

# %%
cat_var
# Out:
# ['bedrooms', 'bathrooms', 'fips']

# %%
sns.boxplot(x='bedrooms', y='square_feet', data=train.sample(1000))
plt.show()
sns.violinplot(x='bathrooms', y='square_feet', data=train.sample(1000))
plt.show()
sns.barplot(x='fips', y='square_feet', data=train.sample(1000))
plt.show()
sns.swarmplot(x='bedrooms', y='tax_value', data=train.sample(1000))
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 69.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 86.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 78.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 3. Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
def plot_variable_pairs(df):
    filename = pairplot1000.png
    
    if os.path.isfile(filename)

# %%
def plot_variable_pairs(train, cont_var, cat_var):
# columns    
    cat_var = ['bedrooms', 'bathrooms', 'fips']
    cont_var = ['square_feet', 'tax_amount', 'tax_value', 'year_built']

    
    sns.lmplot(x='tax_value', y='square_feet', data=train.sample(1000), scatter=True)
    sns.lmplot(x='tax_value', y='year_built', data=train.sample(1000), scatter=True)
    sns.lmplot(x='tax_value', y='tax_amount', data=train.sample(1000), scatter=True)


     
    return train, cont_var, cat_var

# %%
plot_variable_pairs(train, cont_var, cat_var)
# Out:
# (         bedrooms  bathrooms  square_feet  tax_value  year_built  tax_amount  \
#  553191          4        2.0         1556     373090        1923     4579.25
#  1209132         3        2.0         1513      74070        1937      986.55
#  174634          4        2.0         2040     138000        1954     2553.05
#  170584          3        2.0         1834     263870        1959     3139.76
#  2001226         2        2.0         1225     335603        1975     3461.38
#  ...           ...        ...          ...        ...         ...         ...
#  562147          3        2.0         1161      65135        1956     1648.42
#  1530656         3        2.0         2042     130866        1950     1531.56
#  745152          4        2.0         1280      92456        1957     1904.80
#  249374          2        1.0          748     226667        1920     3223.60
#  1333156         3        2.0         1472     528455        1969     6182.88
#
#           fips
#  553191   6037
#  1209132  6037
#  174634   6037
#  170584   6059
#  2001226  6059
#  ...       ...
#  562147   6037
#  1530656  6037
#  745152   6037
#  249374   6037
#  1333156  6059
#
#  [1192919 rows x 7 columns],
#  ['square_feet', 'tax_amount', 'tax_value', 'year_built'],
#  ['bedrooms', 'bathrooms', 'fips'])

# %% [markdown]
# 4. Write a function named plot_categorical_and_continuous_vars that accepts your dataframe and the name of the columns that hold the continuous and categorical features and outputs 3 different plots for visualizing a categorical variable and a continuous variable.

# %%
def plot_categorical_and_continuous_vars(train, cont_var, cat_var):
    
    # columns    
    cat_var = ['bedrooms', 'bathrooms', 'fips']
    cont_var = ['square_feet', 'tax_amount', 'tax_value', 'year_built']

    sns.boxplot(x='bedrooms', y='tax_value', data=train.sample(1000))
    plt.show()
    sns.violinplot(x='bathrooms', y='tax_value', data=train.sample(1000))
    plt.show()
    sns.barplot(x='fips', y='tax_value', data=train.sample(1000))
    plt.show()
    
    return train, cont_var, cat_var

# %%
def plot_categorical_and_continuous_vars(train, cont_var, cat_var):
    
    # columns    
    cat_var = ['bedrooms', 'bathrooms', 'fips']
    cont_var = ['square_feet', 'tax_amount', 'tax_value', 'year_built']

    sns.boxplot(x='bedrooms', y='tax_value', data=train.sample(1000))
    plt.show()
    sns.violinplot(x='bathrooms', y='tax_value', data=train.sample(1000))
    plt.show()
    sns.barplot(x='fips', y='tax_value', data=train.sample(1000))
    plt.show()
    
    return train, cont_var, cat_var

# %%
plot_categorical_and_continuous_vars(train, cont_var, cat_var)
# Out:
# (         bedrooms  bathrooms  square_feet  tax_value  year_built  tax_amount  \
#  553191          4        2.0         1556     373090        1923     4579.25
#  1209132         3        2.0         1513      74070        1937      986.55
#  174634          4        2.0         2040     138000        1954     2553.05
#  170584          3        2.0         1834     263870        1959     3139.76
#  2001226         2        2.0         1225     335603        1975     3461.38
#  ...           ...        ...          ...        ...         ...         ...
#  562147          3        2.0         1161      65135        1956     1648.42
#  1530656         3        2.0         2042     130866        1950     1531.56
#  745152          4        2.0         1280      92456        1957     1904.80
#  249374          2        1.0          748     226667        1920     3223.60
#  1333156         3        2.0         1472     528455        1969     6182.88
#
#           fips
#  553191   6037
#  1209132  6037
#  174634   6037
#  170584   6059
#  2001226  6059
#  ...       ...
#  562147   6037
#  1530656  6037
#  745152   6037
#  249374   6037
#  1333156  6059
#
#  [1192919 rows x 7 columns],
#  ['square_feet', 'tax_amount', 'tax_value', 'year_built'],
#  ['bedrooms', 'bathrooms', 'fips'])
